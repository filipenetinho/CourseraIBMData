# %% [markdown]
# # Python Training
# ## Random User API

# %% [markdown]
# Remember the Get Methods that can be used to generate parameters. More info: [documentation](https://randomuser.me/documentation?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork1005-2022-01-01) page.

# %% [markdown]
# ### Get Methods
#
# - get_cell()
# - get_city()
# - get_dob()
# - get_email()
# - get_first_name()
# - get_full_name()
# - get_gender()
# - get_id()
# - get_id_number()
# - get_id_type()
# - get_info()
# - get_last_name()
# - get_login_md5()
# - get_login_salt()
# - get_login_sha1()
# - get_login_sha256()
# - get_nat()
# - get_password()
# - get_phone()
# - get_picture()
# - get_postcode()
# - get_registered()
# - get_state()
# - get_street()
# - get_username()
# - get_zipcode()

# %% [markdown]
# ### Example

# %%
#To start using the API you can install the randomuser library.
# !pip install randomuser

# %%
#Load the necessary libraries
from randomuser import RandomUser
import pandas as pd

# %%
#Create a random user object, r
r = RandomUser()

# %%
#Using generate_users() function, we get a list of random 10 users
some_list = r.generate_users(10)
some_list

# %% [markdown]
# The "Get Methods" functions mentioned at the beginning of this notebook, can generate the required parameters to construct a dataset. For example, to get full name, we call get_full_name() function.

# %%
name = r.get_full_name()

# %% [markdown]
# Let's say we only need 10 users with full names and their email addresses. We can write a "for-loop" to print these 10 users.

# %%
for user in some_list:
    print (user.get_full_name()," ",user.get_email())
# Out:
# Glen Peck   glen.peck@example.com
# Nikolas Appelt   nikolas.appelt@example.com
# Sophie Wilson   sophie.wilson@example.com
# Iker Ferrer   iker.ferrer@example.com
# Monica Johnston   monica.johnston@example.com
# Katherine Lord   katherine.lord@example.com
# Andreas Johansen   andreas.johansen@example.com
# Eloane Rey   eloane.rey@example.com
# Isla Hatala   isla.hatala@example.com
# Nolan Bishop   nolan.bishop@example.com

# %% [markdown]
# ___

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# Generate photos of the random 5 users.

# %%
for user in some_list:
    print (user.get_picture())
# Out:
# https://randomuser.me/api/portraits/men/89.jpg
# https://randomuser.me/api/portraits/men/8.jpg
# https://randomuser.me/api/portraits/women/76.jpg
# https://randomuser.me/api/portraits/men/39.jpg
# https://randomuser.me/api/portraits/women/32.jpg
# https://randomuser.me/api/portraits/women/48.jpg
# https://randomuser.me/api/portraits/men/11.jpg
# https://randomuser.me/api/portraits/women/9.jpg
# https://randomuser.me/api/portraits/women/53.jpg
# https://randomuser.me/api/portraits/men/11.jpg

# %% [markdown]
# To generate a table with information about the users, we can write a function containing all desirable parameters. For example, name, gender, city, etc. The parameters will depend on the requirements of the test to be performed. We call the Get Methods, listed at the beginning of this notebook. Then, we return pandas dataframe with the users.

# %%
def get_users():
    users =[]
     
    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
      
    return pd.DataFrame(users)     

get_users()
# Out:
#                 Name  Gender               City          State  \
# 0        Kenan Sezek    male               Bolu         Manisa
# 1    Volkan Saygıner    male            Denizli          Niğde
# 2    Jeppe Jørgensen    male             Lemvig    Midtjylland
# 3     Andrea Montero  female           Arrecife          Ceuta
# 4      Brielle Clark  female          Deer Lake  New Brunswick
# 5     Otacília Moura  female  Santa Cruz do Sul      Tocantins
# 6  Babür Düşenkalkar    male             Elazığ        Hakkâri
# 7       Lena Bremnes  female           Svenevik       Nordland
# 8   Allie Cunningham  female           Limerick          Kerry
# 9    Charlie Stokkel  female           Nijeveen   Zuid-Holland
#
#                            Email                       DOB  \
# 0        kenan.sezek@example.com  1986-06-02T22:22:25.047Z
# 1    volkan.sayginer@example.com  1989-07-12T23:43:56.094Z
# 2    jeppe.jorgensen@example.com  1985-12-10T14:11:21.751Z
# ...

# %%
df1 = pd.DataFrame(get_users())  
df1
# Out:
#                  Name  Gender           City               State  \
# 0     Salvador Oliver    male    Rockhampton   Western Australia
# 1     Elijah Bergmann    male         Meldal            Akershus
# 2       Antonio Hicks    male        Raleigh             Georgia
# 3      Chris Haugerud    male  Slettebrotane    Sogn og Fjordane
# 4     Eleanor Jackson  female      Mullingar             Leitrim
# 5    Villads Sørensen    male       Ølstykke             Danmark
# 6       Virginia Moya  female    Ciudad Real  Castilla la Mancha
# 7      Gökhan Babacan    male        Kayseri           Şanlıurfa
# 8  Paul-Heinz Meißner    male        Garbsen              Hessen
# 9      Minnie Shelton  female     Carrollton             Vermont
#
#                              Email                       DOB  \
# 0      salvador.oliver@example.com  1973-06-05T11:24:35.902Z
# 1      elijah.bergmann@example.com  1963-06-21T10:54:01.408Z
# 2        antonio.hicks@example.com  1984-12-08T15:59:47.041Z
# ...

# %% [markdown]
# This last code line generated a _pandas_ dataframe that can be used for any testing purposes.

# %% [markdown]
# ___

# %% [markdown]
# ### Example 2

# %% [markdown]
# Another, more common way to use APIs, is through requests library. The next lab, Requests and HTTP, will contain more information about requests.

# %%
#Import required libraries
import requests
import json

# %%
#Obtain fuitvice API requests.get("url") function
data = requests.get("https://fruityvice.com/api/fruit/all")

#Retrieve results using json.loads() function
results = json.loads(data.text)

#Convert json data into panda df
pd.DataFrame(results)
# Out:
#            genus          name  id           family             order  \
# 0          Malus         Apple   6         Rosaceae           Rosales
# 1         Prunus       Apricot  35         Rosaceae           Rosales
# 2         Persea       Avocado  84        Lauraceae          Laurales
# 3           Musa        Banana   1         Musaceae      Zingiberales
# 4          Rubus    Blackberry  64         Rosaceae           Rosales
# 5       Fragaria     Blueberry  33         Rosaceae           Rosales
# 6         Prunus        Cherry   9         Rosaceae           Rosales
# 7      Vaccinium     Cranberry  87        Ericaceae          Ericales
# 8   Selenicereus   Dragonfruit  80        Cactaceae    Caryophyllales
# 9          Durio        Durian  60        Malvaceae          Malvales
# 10    Sellowiana        Feijoa  76        Myrtaceae        Myrtoideae
# 11         Ficus           Fig  68         Moraceae           Rosales
# ...

# %% [markdown]
# The result is in a nested json format. The 'nutrition' column contains multiple subcolumns, so the data needs to be 'flattened' or normalized.

# %%
df2 = pd.json_normalize(results)
df2
# Out:
#            genus          name  id           family             order  \
# 0          Malus         Apple   6         Rosaceae           Rosales
# 1         Prunus       Apricot  35         Rosaceae           Rosales
# 2         Persea       Avocado  84        Lauraceae          Laurales
# 3           Musa        Banana   1         Musaceae      Zingiberales
# 4          Rubus    Blackberry  64         Rosaceae           Rosales
# 5       Fragaria     Blueberry  33         Rosaceae           Rosales
# 6         Prunus        Cherry   9         Rosaceae           Rosales
# 7      Vaccinium     Cranberry  87        Ericaceae          Ericales
# 8   Selenicereus   Dragonfruit  80        Cactaceae    Caryophyllales
# 9          Durio        Durian  60        Malvaceae          Malvales
# 10    Sellowiana        Feijoa  76        Myrtaceae        Myrtoideae
# 11         Ficus           Fig  68         Moraceae           Rosales
# ...

# %%
#For example, extract the info of the family and genus of a cherry
cherry = df2.loc[df2["name"] == 'Cherry']
(cherry.iloc[0][3]) , (cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')

# %% [markdown]
# ___

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# Find out how many calories are contained in a banana.

# %%
cal_banana = df2.loc[df2["name"] == 'Banana']
cal_banana.iloc[0]['nutritions.calories']
# Out:
# 96

# %% [markdown]
# ### Exercise 3

# %% [markdown]
# Access this [page](https://github.com/public-apis/public-apis#animals) that contains a list of free public APIs. Choose any of them and load/extract some info

# %%
#Load your data
data3 = requests.get("http://dog-api.kinduff.com/api/facts?number=10")

#Retrieve results using json.loads() function
results3 = json.loads(data3.text)

#Convert into pandas df
df3 = pd.DataFrame(results3)
df3
# Out:
#                                                facts  success
# 0  The world’s smartest dogs are thought to be (1...     True
# 1                     Dogs are natural pack animals.     True
# 2  The Border Collie, Poodle and Golden Retriever...     True
# 3  Apple and pear seeds contain arsenic, which ma...     True
# 4  The Newfoundland has a water-resistant coat an...     True
# 5  The phrase "raining cats and dogs" originated ...     True
# 6  In Iran, it is against the law to own a dog as...     True
# 7                        Dogs have no sense of time.     True
# 8  Chocolate contains a substance known as theobr...     True
# 9  Chase that tail! Dogs chase their tails for a ...     True

# %% [markdown]
# ### End :)
